# %% [markdown]
# # Loading SpikeSorting Data

# %%
# Turn off logging, this is a hidden cell on docs page
import logging
logger = logging.getLogger('ibllib')
logger.setLevel(logging.CRITICAL)

# %% [markdown]
# Spikesorted output of electrophysiology data.

# %% [markdown]
# ## Relevant Alf objects
# * channels
# * clusters
# * spikes

# %% [markdown]
# ## Loading

# %%
from one.api import ONE
from brainbox.io.one import SpikeSortingLoader
from ibllib.atlas import AllenAtlas

one = ONE()
ba = AllenAtlas()
pid = 'da8dfec1-d265-44e8-84ce-6ae9c109b8bd' 

sl = SpikeSortingLoader(pid=pid, one=one, atlas=ba)
spikes, clusters, channels = sl.load_spike_sorting()
clusters = sl.merge_clusters(spikes, clusters, channels)
# Out:
# Downloading: /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/histology/ATLAS/Needles/Allen/average_template_25.nrrd Bytes: 32998960
#   0%|          | 0/31.470260620117188 [00:00<?, ?it/s]
#  13%|█▎        | 4.0/31.470260620117188 [00:00<00:03,  7.00it/s]
#  25%|██▌       | 8.0/31.470260620117188 [00:00<00:01, 12.74it/s]
#  51%|█████     | 16.0/31.470260620117188 [00:00<00:00, 23.10it/s]
#  76%|███████▋  | 24.0/31.470260620117188 [00:01<00:00, 29.80it/s]
# 100%|██████████| 31.470260620117188/31.470260620117188 [00:01<00:00, 34.31it/s]
# 100%|██████████| 31.470260620117188/31.470260620117188 [00:01<00:00, 25.53it/s]
# Downloading: /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/histology/ATLAS/Needles/Allen/annotation_25.nrrd Bytes: 4035363
#   0%|          | 0/3.848422050476074 [00:00<?, ?it/s]
# 100%|██████████| 3.848422050476074/3.848422050476074 [00:00<00:00,  6.26it/s]
# 100%|██████████| 3.848422050476074/3.848422050476074 [00:00<00:00,  6.25it/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:   0%|          | 0.00/141M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:   0%|          | 262k/141M [00:00<04:58, 470kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:   1%|          | 1.05M/141M [00:00<01:16, 1.82MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:   3%|▎         | 4.19M/141M [00:00<00:18, 7.40MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:   6%|▌         | 8.65M/141M [00:01<00:11, 11.7MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  10%|█         | 14.7M/141M [00:01<00:06, 19.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  12%|█▏        | 17.3M/141M [00:01<00:08, 15.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  16%|█▋        | 23.1M/141M [00:01<00:05, 22.6MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  20%|██        | 28.6M/141M [00:01<00:03, 28.0MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  26%|██▌       | 36.2M/141M [00:01<00:02, 38.3MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  41%|████      | 57.9M/141M [00:01<00:01, 80.3MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  57%|█████▋    | 80.0M/141M [00:02<00:00, 115MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  68%|██████▊   | 95.4M/141M [00:02<00:00, 126MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  68%|██████▊   | 95.7M/141M [00:02<00:00, 133MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  78%|███████▊  | 110M/141M [00:02<00:00, 134MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy:  90%|████████▉ | 126M/141M [00:02<00:00, 131MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy: 100%|█████████▉| 140M/141M [00:02<00:00, 115MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.amps.npy: 100%|██████████| 141M/141M [00:02<00:00, 54.3MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:   0%|          | 0.00/70.3M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:   0%|          | 262k/70.3M [00:00<01:19, 885kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:   1%|          | 524k/70.3M [00:00<00:49, 1.40MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:  28%|██▊       | 19.9M/70.3M [00:00<00:01, 43.9MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:  29%|██▉       | 20.7M/70.3M [00:00<00:00, 134MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:  32%|███▏      | 22.3M/70.3M [00:00<00:00, 134MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:  33%|███▎      | 23.1M/70.3M [00:00<00:00, 134MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:  75%|███████▍  | 52.7M/70.3M [00:00<00:00, 176MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:  76%|███████▋  | 53.7M/70.3M [00:00<00:00, 260MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:  76%|███████▋  | 53.7M/70.3M [00:00<00:00, 260MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:  77%|███████▋  | 54.0M/70.3M [00:00<00:00, 260MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy:  81%|████████  | 56.9M/70.3M [00:00<00:00, 260MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.clusters.npy: 100%|██████████| 70.3M/70.3M [00:00<00:00, 119MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:   0%|          | 0.00/141M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:   0%|          | 262k/141M [00:00<02:18, 1.01MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  18%|█▊        | 24.6M/141M [00:00<00:01, 87.1MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  18%|█▊        | 24.9M/141M [00:00<00:00, 140MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  41%|████      | 57.9M/141M [00:00<00:00, 201MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  42%|████▏     | 59.5M/141M [00:00<00:00, 313MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  42%|████▏     | 59.5M/141M [00:00<00:00, 313MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  43%|████▎     | 59.8M/141M [00:00<00:00, 313MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  44%|████▍     | 61.6M/141M [00:00<00:00, 313MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  45%|████▍     | 63.2M/141M [00:00<00:00, 313MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  45%|████▌     | 63.7M/141M [00:00<00:00, 313MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  68%|██████▊   | 95.7M/141M [00:00<00:00, 212MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  68%|██████▊   | 96.2M/141M [00:00<00:00, 152MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  69%|██████▉   | 97.5M/141M [00:00<00:00, 152MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  85%|████████▌ | 120M/141M [00:00<00:00, 164MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy:  85%|████████▌ | 120M/141M [00:00<00:00, 176MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.times.npy: 100%|██████████| 141M/141M [00:01<00:00, 136MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:   0%|          | 0.00/141M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:   0%|          | 262k/141M [00:00<02:24, 968kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:  16%|█▌        | 22.0M/141M [00:00<00:01, 73.5MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:  39%|███▉      | 54.8M/141M [00:00<00:00, 156MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:  39%|███▉      | 55.3M/141M [00:00<00:00, 210MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:  58%|█████▊    | 81.3M/141M [00:00<00:00, 203MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:  75%|███████▍  | 105M/141M [00:00<00:00, 181MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:  75%|███████▌  | 106M/141M [00:00<00:00, 158MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:  75%|███████▌  | 106M/141M [00:00<00:00, 158MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:  76%|███████▋  | 107M/141M [00:00<00:00, 158MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy:  88%|████████▊ | 124M/141M [00:00<00:00, 159MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy: 100%|██████████| 141M/141M [00:00<00:00, 154MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.depths.npy: 100%|██████████| 141M/141M [00:01<00:00, 140MB/s]
# Downloading: /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/clusters.depths.3694107b-230d-43d8-aeea-56b4aaf5a384.npy Bytes: 3784Downloading: /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/clusters.channels.b89869a6-541b-4b65-961d-a8f523eec728.npy Bytes: 7440
# Downloading: /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/clusters.uuids.926b88ce-c08e-410d-ba84-c442472d1fed.csv Bytes: 33823
#
# Downloading: /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/clusters.metrics.feae3962-835c-43cf-8f97-539d68b8906d.pqt Bytes: 107637
#   0%|          | 0/0.032256126403808594 [00:00<?, ?it/s]
#   0%|          | 0/0.00360870361328125 [00:00<?, ?it/s]
#   0%|          | 0/0.10265064239501953 [00:00<?, ?it/s]
#   0%|          | 0/0.0070953369140625 [00:00<?, ?it/s]
# 100%|██████████| 0.00360870361328125/0.00360870361328125 [00:00<00:00,  3.52s/it]
# 100%|██████████| 0.0070953369140625/0.0070953369140625 [00:00<00:00,  2.76it/s]
# 100%|██████████| 0.032256126403808594/0.032256126403808594 [00:00<00:00,  1.56it/s]
# 100%|██████████| 0.10265064239501953/0.10265064239501953 [00:00<00:00,  1.59it/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.mlapdv.npy:   0%|          | 0.00/4.74k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.mlapdv.npy: 100%|██████████| 4.74k/4.74k [00:00<00:00, 23.5kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.mlapdv.npy: 100%|██████████| 4.74k/4.74k [00:00<00:00, 23.0kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.rawInd.npy:   0%|          | 0.00/3.20k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.rawInd.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.8kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.rawInd.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.5kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.localCoordinates.npy:   0%|          | 0.00/3.20k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.localCoordinates.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 16.2kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.localCoordinates.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.8kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy:   0%|          | 0.00/3.20k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 14.9kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 14.7kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/electrodeSites.brainLocationIds_ccf_2017.npy:   0%|          | 0.00/3.20k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/electrodeSites.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.9kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/electrodeSites.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.4kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/electrodeSites.mlapdv.npy:   0%|          | 0.00/4.74k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/electrodeSites.mlapdv.npy: 100%|██████████| 4.74k/4.74k [00:00<00:00, 22.4kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/electrodeSites.mlapdv.npy: 100%|██████████| 4.74k/4.74k [00:00<00:00, 22.1kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/electrodeSites.localCoordinates.npy:   0%|          | 0.00/3.20k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/electrodeSites.localCoordinates.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.7kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/electrodeSites.localCoordinates.npy: 100%|██████████| 3.20k/3.20k [00:00<00:00, 15.5kB/s]

# %% [markdown]
# Alternatively, one can instantiate the spike sorting loader using the session unique identifier eid and the probe name pname:

# %%
eid, pname = one.pid2eid(pid)
sl = SpikeSortingLoader(eid=eid, pname=pname, one=one, atlas=ba)
spikes, clusters, channels = sl.load_spike_sorting()
clusters = sl.merge_clusters(spikes, clusters, channels)

# %% [markdown]
# ## More details
# * [Description of spikesorting datasets](https://docs.google.com/document/d/1OqIqqakPakHXRAwceYLwFY9gOrm8_P62XIfCTnHwstg/edit#heading=h.5houj8bng5o)
# * Available spikesorting algorithms
#     * [pykilosort](https://github.com/int-brain-lab/pykilosort#readme) (All data)
#     * [Kilosort 2.5](https://github.com/MouseLand/Kilosort/releases/tag/v2.5) (Most data collected before August 2021)

# %% [markdown]
# ## Important information
# 1. Data sorted with pykilosort is loaded by default. If the pykilosort spikesorting data is not available, the matlab kilosort 2.5 version will be loaded. See [Example 1](#Example-1:-Loading-different-spikesorting-versions) for more information.
# 2. The channel locations in the brain can come from several sources. it will load the most advanced version of the histology available, regardless of the spike sorting version loaded.
# The steps, from most to least advanced, are:
#     * **alf**: the final version of channel locations, same as resolved with the difference that data has been written out to files
#     * **resolved**: channel location alignments have been agreed upon
#     * **aligned**: channel locations have been aligned, but review or other alignments are pending, potentially not accurate
#     * **traced**: the histology track has been recovered from microscopy, however the depths may not match, inacurate data
# 3. The attributes `mlapdv`, `atlas_ids` and `acronyms` in the `clusters` and `channels` objects are only available for probe insertions where `sl.histology` is equal to **traced**, **aligned**, **resolved** or **alf**.
# 4. The cluster and channel locations in the brain are only considered final for probe insertions with `sl.histology='resolved'`or `sl.histology='alf'`.

# %% [markdown]
# ## Useful modules
# * [brainbox.io.one.SpikeSortingLoader](https://int-brain-lab.github.io/iblenv/_autosummary/brainbox.io.one.html#brainbox.io.one.SpikeSortingLoader)
# * [brainbox.ephys_plots](https://int-brain-lab.github.io/iblenv/_autosummary/brainbox.ephys_plots.html)
# * [brainbox.population.decode.get_spike_counts_in_bins](https://int-brain-lab.github.io/iblenv/_autosummary/brainbox.population.decode.html#brainbox.population.decode.get_spike_counts_in_bins)
# * [brainbox.processing](https://int-brain-lab.github.io/iblenv/_autosummary/brainbox.processing.html#brainbox.processing)
# * [brainbox.metrics.single_units](https://int-brain-lab.github.io/iblenv/_autosummary/brainbox.metrics.single_units.html#module-brainbox.metrics.single_units)

# %% [markdown]
# ## Exploring spikesorting data

# %% [markdown]
# ### Example 1: Loading different spikesorting versions

# %%
# By default, if available, the data spikesorted with pykilosort is loaded. 
# To find the spikesorting version that is loaded we can use
sl.collection

# To see all available spikesorted data for this probe insertion we can list the collections. 
# N.B. ks2.5 matlab spikesorted data is stored in the alf/probe00 folder
sl.collections

# The following can be used to load a specific version of spikesorting

# pykilosort version
spikes, clusters, channels = sl.load_spike_sorting(spike_sorter='pykilosort')

# ks2.5 matlab version
spikes, clusters, channels = sl.load_spike_sorting(spike_sorter='')
# Out:
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:   0%|          | 0.00/161M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:   0%|          | 262k/161M [00:00<05:45, 464kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:   1%|          | 1.31M/161M [00:00<01:09, 2.29MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:   3%|▎         | 4.98M/161M [00:00<00:17, 8.74MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:   5%|▌         | 8.65M/161M [00:01<00:14, 10.6MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:   9%|▉         | 14.2M/161M [00:01<00:08, 17.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  11%|█         | 17.0M/161M [00:01<00:08, 16.2MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  15%|█▍        | 23.3M/161M [00:01<00:05, 24.0MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  18%|█▊        | 29.1M/161M [00:01<00:04, 30.8MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  23%|██▎       | 37.5M/161M [00:01<00:02, 42.6MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  35%|███▌      | 56.6M/161M [00:01<00:01, 78.7MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  35%|███▌      | 56.9M/161M [00:01<00:00, 108MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  54%|█████▍    | 87.3M/161M [00:02<00:00, 160MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  55%|█████▍    | 87.8M/161M [00:02<00:00, 200MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  68%|██████▊   | 110M/161M [00:02<00:00, 179MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  80%|████████  | 129M/161M [00:02<00:00, 179MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  80%|████████  | 129M/161M [00:02<00:00, 178MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy:  93%|█████████▎| 149M/161M [00:02<00:00, 183MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.depths.npy: 100%|██████████| 161M/161M [00:02<00:00, 64.8MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.clusters.npy:   0%|          | 0.00/80.4M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.clusters.npy:   0%|          | 262k/80.4M [00:00<01:20, 995kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.clusters.npy:   1%|          | 524k/80.4M [00:00<00:51, 1.56MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.clusters.npy:  31%|███       | 24.6M/80.4M [00:00<00:00, 59.0MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.clusters.npy:  31%|███       | 24.9M/80.4M [00:00<00:00, 106MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.clusters.npy:  75%|███████▍  | 59.9M/80.4M [00:00<00:00, 169MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.clusters.npy: 100%|██████████| 80.4M/80.4M [00:00<00:00, 144MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:   0%|          | 0.00/161M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:   0%|          | 262k/161M [00:00<02:36, 1.02MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  13%|█▎        | 20.2M/161M [00:00<00:01, 71.8MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  13%|█▎        | 20.7M/161M [00:00<00:00, 142MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  13%|█▎        | 21.0M/161M [00:00<00:00, 142MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  34%|███▍      | 54.8M/161M [00:00<00:00, 201MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  50%|█████     | 80.7M/161M [00:00<00:00, 219MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  65%|██████▌   | 105M/161M [00:00<00:00, 169MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  84%|████████▎ | 134M/161M [00:00<00:00, 199MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  85%|████████▍ | 136M/161M [00:00<00:00, 276MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  85%|████████▍ | 136M/161M [00:00<00:00, 276MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  85%|████████▌ | 137M/161M [00:00<00:00, 276MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  86%|████████▌ | 138M/161M [00:00<00:00, 276MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy:  86%|████████▌ | 138M/161M [00:00<00:00, 276MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.amps.npy: 100%|██████████| 161M/161M [00:01<00:00, 122MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:   0%|          | 0.00/161M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:   0%|          | 262k/161M [00:00<02:45, 968kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  10%|█         | 16.5M/161M [00:00<00:02, 56.7MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  12%|█▏        | 18.6M/161M [00:00<00:00, 148MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  12%|█▏        | 18.9M/161M [00:00<00:00, 148MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  12%|█▏        | 19.9M/161M [00:00<00:00, 148MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  13%|█▎        | 20.4M/161M [00:00<00:00, 148MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  14%|█▎        | 21.8M/161M [00:00<00:00, 148MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  14%|█▍        | 22.3M/161M [00:00<00:00, 148MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  23%|██▎       | 37.7M/161M [00:00<00:01, 108MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  25%|██▍       | 39.6M/161M [00:00<00:01, 72.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  25%|██▌       | 40.6M/161M [00:00<00:01, 72.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  25%|██▌       | 40.9M/161M [00:00<00:01, 72.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  25%|██▌       | 40.9M/161M [00:00<00:01, 72.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  26%|██▌       | 41.9M/161M [00:00<00:01, 72.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  27%|██▋       | 43.0M/161M [00:00<00:01, 72.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  27%|██▋       | 43.3M/161M [00:00<00:01, 72.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  46%|████▋     | 74.4M/161M [00:00<00:00, 109MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  46%|████▋     | 74.7M/161M [00:00<00:00, 146MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  59%|█████▊    | 94.1M/161M [00:00<00:00, 124MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  59%|█████▉    | 94.6M/161M [00:00<00:00, 103MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  59%|█████▉    | 95.2M/161M [00:00<00:00, 103MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  76%|███████▋  | 123M/161M [00:01<00:00, 132MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  77%|███████▋  | 124M/161M [00:01<00:00, 204MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  77%|███████▋  | 124M/161M [00:01<00:00, 204MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  77%|███████▋  | 124M/161M [00:01<00:00, 204MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy:  95%|█████████▌| 153M/161M [00:01<00:00, 218MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/spikes.times.npy: 100%|██████████| 161M/161M [00:01<00:00, 134MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.channels.npy:   0%|          | 0.00/6.48k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.channels.npy: 100%|██████████| 6.48k/6.48k [00:00<00:00, 28.8kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.channels.npy: 100%|██████████| 6.48k/6.48k [00:00<00:00, 28.4kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.uuids.csv:   0%|          | 0.00/29.4k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.uuids.csv: 100%|██████████| 29.4k/29.4k [00:00<00:00, 102kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.uuids.csv: 100%|██████████| 29.4k/29.4k [00:00<00:00, 101kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.metrics.pqt:   0%|          | 0.00/97.0k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.metrics.pqt: 100%|██████████| 97.0k/97.0k [00:00<00:00, 335kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.metrics.pqt: 100%|██████████| 97.0k/97.0k [00:00<00:00, 330kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.depths.npy:   0%|          | 0.00/6.48k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.depths.npy: 100%|██████████| 6.48k/6.48k [00:00<00:00, 33.8kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/clusters.depths.npy: 100%|██████████| 6.48k/6.48k [00:00<00:00, 32.9kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.rawInd.npy:   0%|          | 0.00/3.12k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.rawInd.npy: 100%|██████████| 3.12k/3.12k [00:00<00:00, 15.3kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.rawInd.npy: 100%|██████████| 3.12k/3.12k [00:00<00:00, 14.9kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.localCoordinates.npy:   0%|          | 0.00/6.06k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.localCoordinates.npy: 100%|██████████| 6.06k/6.06k [00:00<00:00, 31.0kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.localCoordinates.npy: 100%|██████████| 6.06k/6.06k [00:00<00:00, 30.2kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.brainLocationIds_ccf_2017.npy:   0%|          | 0.00/3.12k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.12k/3.12k [00:00<00:00, 12.7kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.brainLocationIds_ccf_2017.npy: 100%|██████████| 3.12k/3.12k [00:00<00:00, 12.5kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.mlapdv.npy:   0%|          | 0.00/4.62k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.mlapdv.npy: 100%|██████████| 4.62k/4.62k [00:00<00:00, 25.3kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/channels.mlapdv.npy: 100%|██████████| 4.62k/4.62k [00:00<00:00, 24.7kB/s]

# %% [markdown]
# ### Example 2: Loading additional data

# %%
# The default spikes and cluster attributes loaded are:
# spikes - amps, clusters, depths, times
# cluster - channels, depths, metrics

#Other attributes can additionally be loaded in the following way
spikes, clusters, channels = sl.load_spike_sorting(dataset_types=['clusters.amps', 'spikes.samples'])
clusters = sl.merge_clusters(spikes, clusters, channels)
# Out:
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:   0%|          | 0.00/141M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:   0%|          | 262k/141M [00:00<06:28, 361kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:   1%|          | 1.31M/141M [00:00<01:13, 1.89MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:   3%|▎         | 4.46M/141M [00:01<00:20, 6.69MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:   6%|▌         | 8.65M/141M [00:01<00:13, 10.0MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  10%|█         | 14.2M/141M [00:01<00:07, 16.6MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  12%|█▏        | 17.0M/141M [00:01<00:07, 15.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  16%|█▋        | 23.1M/141M [00:01<00:05, 21.8MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  19%|█▊        | 26.2M/141M [00:01<00:04, 23.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  22%|██▏       | 30.9M/141M [00:01<00:03, 28.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  33%|███▎      | 46.7M/141M [00:02<00:01, 58.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  50%|████▉     | 69.7M/141M [00:02<00:00, 101MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  69%|██████▉   | 97.0M/141M [00:02<00:00, 146MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  81%|████████  | 114M/141M [00:02<00:00, 134MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  82%|████████▏ | 115M/141M [00:02<00:00, 127MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy:  92%|█████████▏| 130M/141M [00:02<00:00, 133MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/spikes.samples.npy: 100%|██████████| 141M/141M [00:02<00:00, 52.5MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/#2022-10-31#/clusters.amps.npy:   0%|          | 0.00/7.44k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/#2022-10-31#/clusters.amps.npy: 100%|██████████| 7.44k/7.44k [00:00<00:00, 34.0kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/#2022-10-31#/clusters.amps.npy: 100%|██████████| 7.44k/7.44k [00:00<00:00, 33.4kB/s]

# %% [markdown]
# ### Example 3: Compute firing rate across session

# %%
from brainbox.ephys_plots import image_fr_plot
from brainbox.processing import bincount2D
import numpy as np

time_bin = 0.05 # time bin in seconds
depth_bin = 10 # depth bin in um

# Remove any nan values
kp_idx = np.bitwise_and(~np.isnan(spikes['times']), ~np.isnan(spikes['depths']))

fr, time, depth = bincount2D(spikes['times'][kp_idx], spikes['depths'][kp_idx], time_bin, depth_bin)

# %% [markdown]
# ### Example 4: Find clusters labelled as good

# %%
good_clusterIDs = clusters['cluster_id'][clusters['label'] == 1]

# %% [markdown]
# ### Example 5: Plot a raster for all units

# %%
sl.raster(spikes, channels)
# Out:
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/drift.times.npy:   0%|          | 0.00/15.8k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/drift.times.npy: 100%|██████████| 15.8k/15.8k [00:00<00:00, 82.3kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/drift.times.npy: 100%|██████████| 15.8k/15.8k [00:00<00:00, 78.3kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/drift.um.npy:   0%|          | 0.00/142k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/drift.um.npy: 100%|██████████| 142k/142k [00:00<00:00, 295kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/probe00/pykilosort/drift.um.npy: 100%|██████████| 142k/142k [00:00<00:00, 293kB/s]
# (<Figure size 1600x900 with 4 Axes>,
#  array([[<AxesSubplot: title={'center': '2020-09-21_1_SWC_043_probe00, None \n17_575_242 spikes, 914 clusters'}>,
#          <AxesSubplot: >],
#         [<AxesSubplot: xlabel='time (secs)', ylabel='depth (um)'>,
#          <AxesSubplot: title={'center': 'alf'}>]], dtype=object))

# %% [markdown]
# ## Other relevant examples
# * COMING SOON
