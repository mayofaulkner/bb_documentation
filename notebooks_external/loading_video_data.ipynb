# %% [markdown]
# # Loading Video Data

# %% [markdown]
# Extracted DLC features and motion energy from raw video data

# %% [markdown]
# ## Relevant Alf objects
# * bodyCamera
# * leftCamera
# * rightCamera
# * licks
# * ROIMotionEnergy

# %% [markdown]
# ## Loading

# %%
from one.api import ONE

one = ONE()
eid = '4ecb5d24-f5cc-402c-be28-9d0f7cb14b3a'

label = 'right' # 'left', 'right' or 'body'

video_features = one.load_object(eid, f'{label}Camera', collection='alf')
# Out:
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:   0%|          | 0.00/83.0M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:   0%|          | 262k/83.0M [00:00<02:46, 498kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:   1%|▏         | 1.05M/83.0M [00:00<00:43, 1.86MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:   5%|▍         | 3.93M/83.0M [00:00<00:11, 6.88MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:   9%|▊         | 7.08M/83.0M [00:00<00:06, 11.2MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:  10%|█         | 8.65M/83.0M [00:01<00:10, 6.95MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:  12%|█▏        | 9.96M/83.0M [00:01<00:09, 7.51MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:  19%|█▊        | 15.5M/83.0M [00:01<00:04, 15.6MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:  31%|███       | 25.4M/83.0M [00:01<00:01, 32.1MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:  56%|█████▌    | 46.7M/83.0M [00:01<00:00, 71.5MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:  80%|███████▉  | 66.1M/83.0M [00:01<00:00, 98.9MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt:  95%|█████████▍| 78.5M/83.0M [00:03<00:00, 19.4MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/_ibl_rightCamera.dlc.pqt: 100%|██████████| 83.0M/83.0M [00:06<00:00, 13.5MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:   0%|          | 0.00/9.92M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:   3%|▎         | 262k/9.92M [00:00<00:08, 1.08MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  18%|█▊        | 1.80M/9.92M [00:00<00:01, 5.87MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  26%|██▌       | 2.58M/9.92M [00:00<00:02, 3.21MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  31%|███▏      | 3.11M/9.92M [00:00<00:02, 2.96MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  37%|███▋      | 3.63M/9.92M [00:01<00:02, 2.54MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  42%|████▏     | 4.16M/9.92M [00:01<00:02, 2.51MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  47%|████▋     | 4.68M/9.92M [00:01<00:02, 2.50MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  52%|█████▏    | 5.21M/9.92M [00:01<00:02, 2.28MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  58%|█████▊    | 5.73M/9.92M [00:02<00:01, 2.33MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  60%|██████    | 5.99M/9.92M [00:02<00:01, 2.24MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  66%|██████▌   | 6.52M/9.92M [00:02<00:01, 2.31MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  71%|███████   | 7.04M/9.92M [00:02<00:01, 2.36MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  76%|███████▌  | 7.56M/9.92M [00:02<00:00, 2.39MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  79%|███████▉  | 7.83M/9.92M [00:03<00:00, 2.29MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  84%|████████▍ | 8.35M/9.92M [00:03<00:00, 2.35MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  89%|████████▉ | 8.88M/9.92M [00:03<00:00, 2.39MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt:  95%|█████████▍| 9.40M/9.92M [00:03<00:00, 2.42MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt: 100%|██████████| 9.92M/9.92M [00:03<00:00, 2.69MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.features.pqt: 100%|██████████| 9.92M/9.92M [00:03<00:00, 2.55MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy:   0%|          | 0.00/4.82M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy:   5%|▌         | 262k/4.82M [00:00<00:05, 792kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy:  16%|█▋        | 786k/4.82M [00:00<00:02, 1.59MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy:  27%|██▋       | 1.31M/4.82M [00:00<00:01, 1.96MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy:  38%|███▊      | 1.84M/4.82M [00:00<00:01, 2.43MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy:  49%|████▉     | 2.36M/4.82M [00:01<00:01, 2.45MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy:  60%|█████▉    | 2.88M/4.82M [00:01<00:00, 2.46MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy:  71%|███████   | 3.41M/4.82M [00:01<00:00, 2.76MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy:  82%|████████▏ | 3.93M/4.82M [00:01<00:00, 2.67MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy:  92%|█████████▏| 4.46M/4.82M [00:01<00:00, 2.88MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/_ibl_rightCamera.times.npy: 100%|██████████| 4.82M/4.82M [00:01<00:00, 2.54MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy:   0%|          | 0.00/4.82M [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy:   5%|▌         | 262k/4.82M [00:00<00:06, 720kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy:  16%|█▋        | 786k/4.82M [00:00<00:02, 1.76MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy:  27%|██▋       | 1.31M/4.82M [00:00<00:01, 2.40MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy:  38%|███▊      | 1.84M/4.82M [00:00<00:01, 2.82MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy:  49%|████▉     | 2.36M/4.82M [00:00<00:00, 3.10MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy:  60%|█████▉    | 2.88M/4.82M [00:01<00:00, 3.32MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy:  71%|███████   | 3.41M/4.82M [00:01<00:00, 3.47MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy:  87%|████████▋ | 4.19M/4.82M [00:01<00:00, 3.97MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy:  98%|█████████▊| 4.72M/4.82M [00:01<00:00, 3.90MB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/#2022-01-31#/rightCamera.ROIMotionEnergy.npy: 100%|██████████| 4.82M/4.82M [00:01<00:00, 3.18MB/s]

# %% [markdown]
# ## More details
# * [Description of camera datasets](https://docs.google.com/document/d/1OqIqqakPakHXRAwceYLwFY9gOrm8_P62XIfCTnHwstg/edit#heading=h.yjwa7dpoipz)
# * [Description of DLC pipeline in IBL](https://github.com/int-brain-lab/iblvideo#readme)
# * [Description of DLC QC metrics](https://int-brain-lab.github.io/iblenv/_autosummary/ibllib.qc.dlc.html)
# * [IBL video white paper](https://docs.google.com/document/u/1/d/e/2PACX-1vS2777bCbDmMre-wyeDr4t0jC-0YsV_uLtYkfS3h9zTwgC7qeMk-GUqxPqcY7ylH17I1Vo1nIuuj26L/pub)

# %% [markdown]
# ## Useful modules
# * [brainbox.behavior.dlc](https://int-brain-lab.github.io/iblenv/_autosummary/brainbox.behavior.dlc.html)
# * [ibllib.qc.dlc](https://int-brain-lab.github.io/iblenv/_autosummary/ibllib.qc.dlc.html)

# %% [markdown]
# ## Exploring video data

# %% [markdown]
# ### Example 1: Filtering dlc features by likelihood threshold

# %%
# Set values with likelihood below chosen threshold to NaN
from brainbox.behavior.dlc import likelihood_threshold

dlc = likelihood_threshold(video_features['dlc'], threshold=0.9)

# %% [markdown]
# ### Example 2: Compute speed of dlc feature

# %%
from brainbox.behavior.dlc import get_speed

# Compute the speed of the right paw
feature = 'paw_r'
dlc_times = video_features['times']
paw_r_speed = get_speed(dlc, dlc_times, label, feature=feature)

# %% [markdown]
# ### Example 3: Plot raster of lick times around feedback event

# %%
# Turn off logging, this is a hidden cell on docs page
import logging
logger = logging.getLogger('ibllib')
logger.setLevel(logging.CRITICAL)

# %%
licks = one.load_object(eid, 'licks', collection='alf')
trials = one.load_object(eid, 'trials', collection='alf')

from brainbox.behavior.dlc import plot_lick_raster
fig = plot_lick_raster(licks['times'], trials.to_df())
# Out:
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/licks.times.npy:   0%|          | 0.00/498k [00:00<?, ?B/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/licks.times.npy:  53%|█████▎    | 262k/498k [00:00<00:00, 509kB/s]
# /home/runner/Downloads/ONE/openalyx.internationalbrainlab.org/hoferlab/Subjects/SWC_043/2020-09-21/001/alf/licks.times.npy: 100%|██████████| 498k/498k [00:00<00:00, 955kB/s]

# %% [markdown]
# ## Other relevant examples
# * COMING SOON
